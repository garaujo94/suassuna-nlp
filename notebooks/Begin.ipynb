# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
for token in doc.ents:
    print(token.text, token.label_)
# Out:
# Apple ORG
# U.K. GPE
# $1 billion MONEY

# %%
doc1 = nlp("I like salty fries and hamburgers hamburgers hamburgers.")
doc2 = nlp("Fast food tastes very good.")

# Similarity of two documents
print(doc1, "<->", doc2, doc1.similarity(doc2))
# Out:
# I like salty fries and hamburgers hamburgers hamburgers. <-> Fast food tastes very good. 0.6829477422387754

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %%
words = [token.text
         for token in doc1
         if not token.is_stop and not token.is_punct]
words
# Out:
# ['like', 'salty', 'fries', 'hamburgers', 'hamburgers', 'hamburgers']

# %%
dicionario = Counter(words)
print(dicionario)
# Out:
# Counter({'hamburgers': 3, 'like': 1, 'salty': 1, 'fries': 1})

# %%
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800).fit_words(dicionario)
plt.imshow(wc , interpolation = 'bilinear')
plt.show()
